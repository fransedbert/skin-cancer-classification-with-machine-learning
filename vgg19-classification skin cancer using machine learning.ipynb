# %% [markdown]
# **VGG-19**
#
# **Skin Cancer Classification using Machine Learning**
#
# **Dataset HAM10000 :** https://drive.google.com/drive/u/1/folders/1fu1yw737pQ3YM53OWTwJ-2l3bNqyk3_2

# %%
# %matplotlib inline
# python libraties
import os, cv2,itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob
from PIL import Image

# pytorch libraries
import torch
from torch import optim,nn
from torch.autograd import Variable
from torch.utils.data import DataLoader,Dataset
from torchvision import models,transforms

# sklearn libraries
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# to make the results are reproducible
np.random.seed(10)
torch.manual_seed(10)
torch.cuda.manual_seed(10)

print(os.listdir("../input"))
# Out:
# ['hmnist_8_8_RGB.csv', 'hmnist_28_28_RGB.csv', 'HAM10000_images_part_1', 'ham10000_images_part_1', 'hmnist_8_8_L.csv', 'HAM10000_images_part_2', 'ham10000_images_part_2', 'hmnist_28_28_L.csv', 'HAM10000_metadata.csv']

# %%
data_dir = '../input'
all_image_path = glob(os.path.join(data_dir, '*', '*.jpg'))
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in all_image_path}
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'dermatofibroma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
def compute_img_mean_std(image_paths):
    """
        computing the mean and std of three channel on the whole dataset,
        first we should normalize the image from 0-255 to 0-1
    """

    img_h, img_w = 224, 224
    imgs = []
    means, stdevs = [], []

    for i in tqdm(range(len(image_paths))):
        img = cv2.imread(image_paths[i])
        img = cv2.resize(img, (img_h, img_w))
        imgs.append(img)

    imgs = np.stack(imgs, axis=3)
    print(imgs.shape)

    imgs = imgs.astype(np.float32) / 255.

    for i in range(3):
        pixels = imgs[:, :, i, :].ravel()  # resize to one row
        means.append(np.mean(pixels))
        stdevs.append(np.std(pixels))

    means.reverse()  # BGR --> RGB
    stdevs.reverse()

    print("normMean = {}".format(means))
    print("normStd = {}".format(stdevs))
    return means,stdevs

# %%
norm_mean,norm_std = compute_img_mean_std(all_image_path)
# Out:
# 100%|██████████| 20030/20030 [06:10<00:00, 54.12it/s]
# (224, 224, 3, 20030)
# normMean = [0.7630448, 0.5456466, 0.57004493]
# normStd = [0.14092787, 0.15261325, 0.16997057]

# %%
# this will tell us how many images are associated with each lesion_id
df_undup = df_original.groupby('lesion_id').count()
# now we filter out lesion_id's that have only one image associated with it
df_undup = df_undup[df_undup['image_id'] == 1]
df_undup.reset_index(inplace=True)
df_undup.head()
# Out:
#      lesion_id  image_id  dx      ...        path  cell_type  cell_type_idx
# 0  HAM_0000001         1   1      ...           1          1              1
# 1  HAM_0000003         1   1      ...           1          1              1
# 2  HAM_0000004         1   1      ...           1          1              1
# 3  HAM_0000007         1   1      ...           1          1              1
# 4  HAM_0000008         1   1      ...           1          1              1
#
# [5 rows x 10 columns]

# %%
# here we identify lesion_id's that have duplicate images and those that have only one image.
def get_duplicates(x):
    unique_list = list(df_undup['lesion_id'])
    if x in unique_list:
        return 'unduplicated'
    else:
        return 'duplicated'

# create a new colum that is a copy of the lesion_id column
df_original['duplicates'] = df_original['lesion_id']
# apply the function to this new column
df_original['duplicates'] = df_original['duplicates'].apply(get_duplicates)
df_original.head()
# Out:
#      lesion_id      image_id     ...     cell_type_idx  duplicates
# 0  HAM_0000118  ISIC_0027419     ...                 2  duplicated
# 1  HAM_0000118  ISIC_0025030     ...                 2  duplicated
# 2  HAM_0002730  ISIC_0026769     ...                 2  duplicated
# 3  HAM_0002730  ISIC_0025661     ...                 2  duplicated
# 4  HAM_0001466  ISIC_0031633     ...                 2  duplicated
#
# [5 rows x 11 columns]

# %%
df_original['duplicates'].value_counts()
# Out:
# unduplicated    5514
# duplicated      4501
# Name: duplicates, dtype: int64

# %%
# now we filter out images that don't have duplicates
df_undup = df_original[df_original['duplicates'] == 'unduplicated']
df_undup.shape
# Out:
# (5514, 11)

# %%
# now we create a val set using df because we are sure that none of these images have augmented duplicates in the train set
y = df_undup['cell_type_idx']
_, df_val = train_test_split(df_undup, test_size=0.2, random_state=101, stratify=y)
df_val.shape
# Out:
# (1103, 11)

# %%
df_val['cell_type_idx'].value_counts()
# Out:
# 4    883
# 2     88
# 6     46
# 1     35
# 0     30
# 5     13
# 3      8
# Name: cell_type_idx, dtype: int64

# %%
# This set will be df_original excluding all rows that are in the val set
# This function identifies if an image is part of the train or val set.
def get_val_rows(x):
    # create a list of all the lesion_id's in the val set
    val_list = list(df_val['image_id'])
    if str(x) in val_list:
        return 'val'
    else:
        return 'train'

# identify train and val rows
# create a new colum that is a copy of the image_id column
df_original['train_or_val'] = df_original['image_id']
# apply the function to this new column
df_original['train_or_val'] = df_original['train_or_val'].apply(get_val_rows)
# filter out train rows
df_train = df_original[df_original['train_or_val'] == 'train']
print(len(df_train))
print(len(df_val))
# Out:
# 8912
# 1103

# %%
df_train['cell_type_idx'].value_counts()
# Out:
# 4    5822
# 6    1067
# 2    1011
# 1     479
# 0     297
# 5     129
# 3     107
# Name: cell_type_idx, dtype: int64

# %%
df_val['cell_type'].value_counts()
# Out:
# Melanocytic nevi                  883
# Benign keratosis-like lesions      88
# dermatofibroma                     46
# Basal cell carcinoma               35
# Actinic keratoses                  30
# Vascular lesions                   13
# Dermatofibroma                      8
# Name: cell_type, dtype: int64

# %%
# Copy fewer class to balance the number of 7 classes
data_aug_rate = [15,10,5,50,0,40,5]
for i in range(7):
    if data_aug_rate[i]:
        df_train=df_train.append([df_train.loc[df_train['cell_type_idx'] == i,:]]*(data_aug_rate[i]-1), ignore_index=True)
df_train['cell_type'].value_counts()
# Out:
# Melanocytic nevi                  5822
# Dermatofibroma                    5350
# dermatofibroma                    5335
# Vascular lesions                  5160
# Benign keratosis-like lesions     5055
# Basal cell carcinoma              4790
# Actinic keratoses                 4455
# Name: cell_type, dtype: int64

# %%
# # We can split the test set again in a validation set and a true test set:
# df_val, df_test = train_test_split(df_val, test_size=0.5)
df_train = df_train.reset_index()
df_val = df_val.reset_index()
# df_test = df_test.reset_index()

# %%
# feature_extract is a boolean that defines if we are finetuning or feature extracting. 
# If feature_extract = False, the model is finetuned and all model parameters are updated. 
# If feature_extract = True, only the last layer parameters are updated, the others remain fixed.
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet18, resnet34, resnet50, resnet101
        """
        model_ft = models.resnet50(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224


    elif model_name == "vgg":
        """ VGG19
        """
        model_ft = models.vgg19(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224


    elif model_name == "densenet":
        """ Densenet121
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()
    return model_ft, input_size

# %%
# resnet,vgg,densenet,inception
model_name = 'vgg'
num_classes = 7
feature_extract = False
# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)
# Define the device:
device = torch.device('cuda:0')
# Put the model on the device:
model = model_ft.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11_bn-6002323d.pth" to /root/.torch/models/vgg11_bn-6002323d.pth
# 531503671it [00:30, 17483326.29it/s]

# %%
# norm_mean = (0.49139968, 0.48215827, 0.44653124)
# norm_std = (0.24703233, 0.24348505, 0.26158768)
# define the transformation of the train images.
train_transform = transforms.Compose([transforms.Resize((input_size,input_size)),transforms.RandomHorizontalFlip(),
                                      transforms.RandomVerticalFlip(),transforms.RandomRotation(20),
                                      transforms.ColorJitter(brightness=0.1, contrast=0.1, hue=0.1),
                                        transforms.ToTensor(), transforms.Normalize(norm_mean, norm_std)])
# define the transformation of the val images.
val_transform = transforms.Compose([transforms.Resize((input_size,input_size)), transforms.ToTensor(),
                                    transforms.Normalize(norm_mean, norm_std)])

# %%
# Define a pytorch dataloader for this dataset
class HAM10000(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        # Load data and get label
        X = Image.open(self.df['path'][index])
        y = torch.tensor(int(self.df['cell_type_idx'][index]))

        if self.transform:
            X = self.transform(X)

        return X, y

# %%
# Define the training set using the table train_df and using our defined transitions (train_transform)
training_set = HAM10000(df_train, transform=train_transform)
train_loader = DataLoader(training_set, batch_size=32, shuffle=True, num_workers=4)
# Same for the validation set:
validation_set = HAM10000(df_val, transform=train_transform)
val_loader = DataLoader(validation_set, batch_size=32, shuffle=False, num_workers=4)

# %%
# we use Adam optimizer, use cross entropy loss as our loss function
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss().to(device)

# %%
# this function is used during training process, to calculation the loss and accuracy
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
total_loss_train, total_acc_train = [],[]
def train(train_loader, model, criterion, optimizer, epoch):
    model.train()
    train_loss = AverageMeter()
    train_acc = AverageMeter()
    curr_iter = (epoch - 1) * len(train_loader)
    for i, data in enumerate(train_loader):
        images, labels = data
        N = images.size(0)
        # print('image shape:',images.size(0), 'label shape',labels.size(0))
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        prediction = outputs.max(1, keepdim=True)[1]
        train_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)
        train_loss.update(loss.item())
        curr_iter += 1
        if (i + 1) % 100 == 0:
            print('[epoch %d], [iter %d / %d], [train loss %.5f], [train acc %.5f]' % (
                epoch, i + 1, len(train_loader), train_loss.avg, train_acc.avg))
            total_loss_train.append(train_loss.avg)
            total_acc_train.append(train_acc.avg)
    return train_loss.avg, train_acc.avg

# %%
def validate(val_loader, model, criterion, optimizer, epoch):
    model.eval()
    val_loss = AverageMeter()
    val_acc = AverageMeter()
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            images, labels = data
            N = images.size(0)
            images = Variable(images).to(device)
            labels = Variable(labels).to(device)

            outputs = model(images)
            prediction = outputs.max(1, keepdim=True)[1]

            val_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)

            val_loss.update(criterion(outputs, labels).item())

    print('------------------------------------------------------------')
    print('[epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, val_loss.avg, val_acc.avg))
    print('------------------------------------------------------------')
    return val_loss.avg, val_acc.avg

# %%
epoch_num = 10
best_val_acc = 0
total_loss_val, total_acc_val = [],[]
for epoch in range(1, epoch_num+1):
    loss_train, acc_train = train(train_loader, model, criterion, optimizer, epoch)
    loss_val, acc_val = validate(val_loader, model, criterion, optimizer, epoch)
    total_loss_val.append(loss_val)
    total_acc_val.append(acc_val)
    if acc_val > best_val_acc:
        best_val_acc = acc_val
        print('*****************************************************')
        print('best record: [epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, loss_val, acc_val))
        print('*****************************************************')
# Out:
# [epoch 1], [iter 100 / 1124], [train loss 1.70426], [train acc 0.32125]
# [epoch 1], [iter 200 / 1124], [train loss 1.56378], [train acc 0.38078]
# [epoch 1], [iter 300 / 1124], [train loss 1.47640], [train acc 0.42615]
# [epoch 1], [iter 400 / 1124], [train loss 1.42080], [train acc 0.45398]
# [epoch 1], [iter 500 / 1124], [train loss 1.38152], [train acc 0.47244]
# [epoch 1], [iter 600 / 1124], [train loss 1.34291], [train acc 0.49130]
# [epoch 1], [iter 700 / 1124], [train loss 1.30646], [train acc 0.50545]
# [epoch 1], [iter 800 / 1124], [train loss 1.27762], [train acc 0.51687]
# [epoch 1], [iter 900 / 1124], [train loss 1.26055], [train acc 0.52580]
# [epoch 1], [iter 1000 / 1124], [train loss 1.23814], [train acc 0.53519]
# [epoch 1], [iter 1100 / 1124], [train loss 1.21906], [train acc 0.54415]
# ------------------------------------------------------------
# [epoch 1], [val loss 0.60303], [val acc 0.80155]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 1], [val loss 0.60303], [val acc 0.80155]
# *****************************************************
# [epoch 2], [iter 100 / 1124], [train loss 0.92544], [train acc 0.66625]
# [epoch 2], [iter 200 / 1124], [train loss 0.92959], [train acc 0.66469]
# [epoch 2], [iter 300 / 1124], [train loss 0.92819], [train acc 0.66448]
# [epoch 2], [iter 400 / 1124], [train loss 0.91920], [train acc 0.66711]
# [epoch 2], [iter 500 / 1124], [train loss 0.91046], [train acc 0.66912]
# [epoch 2], [iter 600 / 1124], [train loss 0.90776], [train acc 0.66927]
# [epoch 2], [iter 700 / 1124], [train loss 0.90505], [train acc 0.66924]
# [epoch 2], [iter 800 / 1124], [train loss 0.89795], [train acc 0.67184]
# [epoch 2], [iter 900 / 1124], [train loss 0.88997], [train acc 0.67490]
# [epoch 2], [iter 1000 / 1124], [train loss 0.88479], [train acc 0.67653]
# [epoch 2], [iter 1100 / 1124], [train loss 0.87225], [train acc 0.68068]
# ------------------------------------------------------------
# [epoch 2], [val loss 0.47325], [val acc 0.83268]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 2], [val loss 0.47325], [val acc 0.83268]
# *****************************************************
# [epoch 3], [iter 100 / 1124], [train loss 0.74107], [train acc 0.73250]
# [epoch 3], [iter 200 / 1124], [train loss 0.71978], [train acc 0.73219]
# [epoch 3], [iter 300 / 1124], [train loss 0.72425], [train acc 0.73333]
# [epoch 3], [iter 400 / 1124], [train loss 0.71907], [train acc 0.73359]
# [epoch 3], [iter 500 / 1124], [train loss 0.71382], [train acc 0.73531]
# [epoch 3], [iter 600 / 1124], [train loss 0.71140], [train acc 0.73443]
# [epoch 3], [iter 700 / 1124], [train loss 0.71036], [train acc 0.73491]
# [epoch 3], [iter 800 / 1124], [train loss 0.71415], [train acc 0.73520]
# [epoch 3], [iter 900 / 1124], [train loss 0.71523], [train acc 0.73566]
# [epoch 3], [iter 1000 / 1124], [train loss 0.71555], [train acc 0.73534]
# [epoch 3], [iter 1100 / 1124], [train loss 0.71136], [train acc 0.73764]
# ------------------------------------------------------------
# [epoch 3], [val loss 0.51128], [val acc 0.81214]
# ------------------------------------------------------------
# [epoch 4], [iter 100 / 1124], [train loss 0.72844], [train acc 0.73313]
# [epoch 4], [iter 200 / 1124], [train loss 0.77049], [train acc 0.72766]
# [epoch 4], [iter 300 / 1124], [train loss 0.79351], [train acc 0.71990]
# [epoch 4], [iter 400 / 1124], [train loss 0.75577], [train acc 0.73023]
# [epoch 4], [iter 500 / 1124], [train loss 0.73119], [train acc 0.73619]
# [epoch 4], [iter 600 / 1124], [train loss 0.72136], [train acc 0.73776]
# [epoch 4], [iter 700 / 1124], [train loss 0.71175], [train acc 0.74103]
# [epoch 4], [iter 800 / 1124], [train loss 0.70087], [train acc 0.74551]
# [epoch 4], [iter 900 / 1124], [train loss 0.69301], [train acc 0.74785]
# [epoch 4], [iter 1000 / 1124], [train loss 0.68320], [train acc 0.75113]
# [epoch 4], [iter 1100 / 1124], [train loss 0.68034], [train acc 0.75224]
# ------------------------------------------------------------
# [epoch 4], [val loss 0.41133], [val acc 0.85244]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 4], [val loss 0.41133], [val acc 0.85244]
# *****************************************************
# [epoch 5], [iter 100 / 1124], [train loss 0.61489], [train acc 0.76969]
# [epoch 5], [iter 200 / 1124], [train loss 0.58704], [train acc 0.78234]
# [epoch 5], [iter 300 / 1124], [train loss 0.58126], [train acc 0.78167]
# [epoch 5], [iter 400 / 1124], [train loss 0.58566], [train acc 0.78180]
# [epoch 5], [iter 500 / 1124], [train loss 0.58997], [train acc 0.77963]
# [epoch 5], [iter 600 / 1124], [train loss 0.58493], [train acc 0.78151]
# [epoch 5], [iter 700 / 1124], [train loss 0.57704], [train acc 0.78357]
# [epoch 5], [iter 800 / 1124], [train loss 0.57358], [train acc 0.78375]
# [epoch 5], [iter 900 / 1124], [train loss 0.56825], [train acc 0.78510]
# [epoch 5], [iter 1000 / 1124], [train loss 0.56646], [train acc 0.78550]
# [epoch 5], [iter 1100 / 1124], [train loss 0.56151], [train acc 0.78798]
# ------------------------------------------------------------
# [epoch 5], [val loss 0.68425], [val acc 0.73946]
# ------------------------------------------------------------
# [epoch 6], [iter 100 / 1124], [train loss 0.53049], [train acc 0.79656]
# [epoch 6], [iter 200 / 1124], [train loss 0.52785], [train acc 0.79828]
# [epoch 6], [iter 300 / 1124], [train loss 0.54028], [train acc 0.79792]
# [epoch 6], [iter 400 / 1124], [train loss 0.54099], [train acc 0.79633]
# [epoch 6], [iter 500 / 1124], [train loss 0.53655], [train acc 0.79881]
# [epoch 6], [iter 600 / 1124], [train loss 0.52965], [train acc 0.80073]
# [epoch 6], [iter 700 / 1124], [train loss 0.53132], [train acc 0.80183]
# [epoch 6], [iter 800 / 1124], [train loss 0.52647], [train acc 0.80418]
# [epoch 6], [iter 900 / 1124], [train loss 0.52224], [train acc 0.80583]
# [epoch 6], [iter 1000 / 1124], [train loss 0.51764], [train acc 0.80688]
# [epoch 6], [iter 1100 / 1124], [train loss 0.51481], [train acc 0.80730]
# ------------------------------------------------------------
# [epoch 6], [val loss 0.37887], [val acc 0.86595]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 6], [val loss 0.37887], [val acc 0.86595]
# *****************************************************
# [epoch 7], [iter 100 / 1124], [train loss 0.49204], [train acc 0.81156]
# [epoch 7], [iter 200 / 1124], [train loss 0.49783], [train acc 0.81078]
# [epoch 7], [iter 300 / 1124], [train loss 0.49157], [train acc 0.81563]
# [epoch 7], [iter 400 / 1124], [train loss 0.50148], [train acc 0.81203]
# [epoch 7], [iter 500 / 1124], [train loss 0.51521], [train acc 0.80881]
# [epoch 7], [iter 600 / 1124], [train loss 0.53638], [train acc 0.80370]
# [epoch 7], [iter 700 / 1124], [train loss 0.53650], [train acc 0.80330]
# [epoch 7], [iter 800 / 1124], [train loss 0.53341], [train acc 0.80480]
# [epoch 7], [iter 900 / 1124], [train loss 0.52645], [train acc 0.80663]
# [epoch 7], [iter 1000 / 1124], [train loss 0.52110], [train acc 0.80737]
# [epoch 7], [iter 1100 / 1124], [train loss 0.51503], [train acc 0.80912]
# ------------------------------------------------------------
# [epoch 7], [val loss 0.42133], [val acc 0.83446]
# ------------------------------------------------------------
# [epoch 8], [iter 100 / 1124], [train loss 0.44584], [train acc 0.83781]
# [epoch 8], [iter 200 / 1124], [train loss 0.45402], [train acc 0.82922]
# [epoch 8], [iter 300 / 1124], [train loss 0.45329], [train acc 0.83000]
# [epoch 8], [iter 400 / 1124], [train loss 0.45227], [train acc 0.82922]
# [epoch 8], [iter 500 / 1124], [train loss 0.44768], [train acc 0.82969]
# [epoch 8], [iter 600 / 1124], [train loss 0.43981], [train acc 0.83219]
# [epoch 8], [iter 700 / 1124], [train loss 0.44050], [train acc 0.83192]
# [epoch 8], [iter 800 / 1124], [train loss 0.44193], [train acc 0.83164]
# [epoch 8], [iter 900 / 1124], [train loss 0.43699], [train acc 0.83382]
# [epoch 8], [iter 1000 / 1124], [train loss 0.43781], [train acc 0.83359]
# [epoch 8], [iter 1100 / 1124], [train loss 0.43572], [train acc 0.83452]
# ------------------------------------------------------------
# [epoch 8], [val loss 0.42165], [val acc 0.84542]
# ------------------------------------------------------------
# [epoch 9], [iter 100 / 1124], [train loss 0.40151], [train acc 0.84469]
# [epoch 9], [iter 200 / 1124], [train loss 0.41117], [train acc 0.84719]
# [epoch 9], [iter 300 / 1124], [train loss 0.41887], [train acc 0.84469]
# [epoch 9], [iter 400 / 1124], [train loss 0.43057], [train acc 0.84070]
# [epoch 9], [iter 500 / 1124], [train loss 0.42968], [train acc 0.84037]
# [epoch 9], [iter 600 / 1124], [train loss 0.42447], [train acc 0.84109]
# [epoch 9], [iter 700 / 1124], [train loss 0.42514], [train acc 0.84067]
# [epoch 9], [iter 800 / 1124], [train loss 0.42669], [train acc 0.84090]
# [epoch 9], [iter 900 / 1124], [train loss 0.42606], [train acc 0.84038]
# [epoch 9], [iter 1000 / 1124], [train loss 0.42494], [train acc 0.84069]
# [epoch 9], [iter 1100 / 1124], [train loss 0.42103], [train acc 0.84139]
# ------------------------------------------------------------
# [epoch 9], [val loss 0.43074], [val acc 0.83714]
# ------------------------------------------------------------
# [epoch 10], [iter 100 / 1124], [train loss 0.36797], [train acc 0.86000]
# [epoch 10], [iter 200 / 1124], [train loss 0.37713], [train acc 0.85859]
# [epoch 10], [iter 300 / 1124], [train loss 0.36752], [train acc 0.86073]
# [epoch 10], [iter 400 / 1124], [train loss 0.38287], [train acc 0.85508]
# [epoch 10], [iter 500 / 1124], [train loss 0.38986], [train acc 0.85113]
# [epoch 10], [iter 600 / 1124], [train loss 0.38809], [train acc 0.85271]
# [epoch 10], [iter 700 / 1124], [train loss 0.39205], [train acc 0.85125]
# [epoch 10], [iter 800 / 1124], [train loss 0.39003], [train acc 0.85203]
# [epoch 10], [iter 900 / 1124], [train loss 0.39360], [train acc 0.85219]
# [epoch 10], [iter 1000 / 1124], [train loss 0.39220], [train acc 0.85175]
# [epoch 10], [iter 1100 / 1124], [train loss 0.38985], [train acc 0.85273]
# ------------------------------------------------------------
# [epoch 10], [val loss 0.40294], [val acc 0.85423]
# ------------------------------------------------------------

# %%
fig = plt.figure(num = 2)
fig1 = fig.add_subplot(2,1,1)
fig2 = fig.add_subplot(2,1,2)
fig1.plot(total_loss_train, label = 'training loss')
fig1.plot(total_acc_train, label = 'training accuracy')
fig2.plot(total_loss_val, label = 'validation loss')
fig2.plot(total_acc_val, label = 'validation accuracy')
plt.legend()
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
model.eval()
y_label = []
y_predict = []
with torch.no_grad():
    for i, data in enumerate(val_loader):
        images, labels = data
        N = images.size(0)
        images = Variable(images).to(device)
        outputs = model(images)
        prediction = outputs.max(1, keepdim=True)[1]
        y_label.extend(labels.cpu().numpy())
        y_predict.extend(np.squeeze(prediction.cpu().numpy().T))

# compute the confusion matrix
confusion_mtx = confusion_matrix(y_label, y_predict)
# plot the confusion matrix
plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'nv', 'vasc','mel']
plot_confusion_matrix(confusion_mtx, plot_labels)

# %%
# Generate a classification report
report = classification_report(y_label, y_predict, target_names=plot_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.58      0.63      0.60        30
#          bcc       0.72      0.83      0.77        35
#          bkl       0.54      0.74      0.62        88
#           df       0.38      0.75      0.50         8
#           nv       0.99      0.89      0.94       883
#         vasc       0.89      0.62      0.73        13
#          mel       0.31      0.59      0.41        46
#
#    micro avg       0.86      0.86      0.86      1103
#    macro avg       0.63      0.72      0.65      1103
# weighted avg       0.90      0.86      0.87      1103

# %%
label_frac_error = 1 - np.diag(confusion_mtx) / np.sum(confusion_mtx, axis=1)
plt.bar(np.arange(7),label_frac_error)
plt.xlabel('True Label')
plt.ylabel('Fraction classified incorrectly')
# Out:
# Text(0, 0.5, 'Fraction classified incorrectly')
